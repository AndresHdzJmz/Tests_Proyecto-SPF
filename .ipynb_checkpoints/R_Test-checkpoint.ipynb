# %% [markdown]
# <img style="float: left; margin: 30px 15px 15px 15px;" src="https://pngimage.net/wp-content/uploads/2018/06/logo-iteso-png-5.png" width="300" height="500" />
#
#
# ### <font color='navy'> Simulación de procesos financieros.
#
# **Nombres:** Rubén Hernández Guevara | Andrés Hernández Jiménez.
#
# **Fecha:** 09 de Marzo del 2021.
#
# **Expediente** : 717710 | 717895.
# **Profesor:** Oscar David Jaramillo Zuluaga.
#
# **Link Github**: https://github.com/Rub27182n/Proyecto-SPF.git
#
# # Proyecto TEMA-2

# %%
# <font color='midnightblue'>

# %% [markdown]
# # <font color='midnightblue'> 1. Análisis y Simulación de Videos de Youtube
#
# > En este proyecto, examinaremos a detalle y simularemos las variables más escenciales de un video de YouTube: Likes, Dislikes, Comments y Views para obtener los estadísticos más probables de un hipotético video.

# %% [markdown]
# # <font color='midnightblue'> 2 . Objetivos

# %% [markdown]
# > ###  <font color='midnightblue'> Generales
# >> Consideramos como objetivo principal, el generar un modelo/función que permita simular, a partir de parámetros o características clave de un video de YouTube, sus principales estádisticos.
#
# > ###  <font color='midnightblue'> Específicos
# >> - Encontrar las categorías de video más populares y etiquetarlas.
# >> - Obtener la Función de Distribución de Probabilidad de cada estadístico para las categorías más populares.
# >> - Simular cantidad de Likes, Dislikes, Comments y Views para las categorías más populares.

# %% [markdown]
# # <font color='midnightblue'> 3.  Definición del Problema
#
# > En este proyecto queremos plantear la idea de una compañía que opera con Data Science,  y que a través de una base de datos de videos de YouTube, le es posible obtener distribuciones de probabilidad y simular casos específicos de hipotéticos videos, a los cuales se pretende estimar su recibimiento (número de vistas, likes, dislikes y comentarios) en la plataforma.
#
# > Todos los datos que se utilizarán son datos reales de videos en Youtube México y YouTube Estados Unidos. Con los 4 estadísticos previamente mencionados, se podrá obtener la información necesaria para evaluar las diferentes categorías de videos y su recibimiento en la plataforma a través de simulación Monte Carlo. Estos parámetros serán los nodos para trabajar específicamente y a través de estos se generarán datos que nos permiten cumplir con el objetivo central, examinar a detalle y simular las variables escenciales de un video de YouTube.

# %%
from IPython import display 
display.Image("./diagrama.png")

# %% [markdown]
# # <font color='midnightblue'> 4. Nodos/Variables a Simular

# %% [markdown]
# > Los nodos/variables que elegimos son:
# > - Número de Vistas
# > - Cantidad de Likes
# > - Cantidad de Dislikes
# > - Número de Comentarios
# > - Categoría de Videos
#
# > Estos nodos fueron elegidos porque generamos la hipótesis de que intrínsecamente están correlacioandos y además se pueden simular ante el supuesto de un video ingresado en la red y su desempeño en la plataforma. La categoría de video es un filtro fundamental para poder separar los resultados de acuerdo con lo que la gente quiere ver basándonos en su popularidad actual. La ratio entre likes y dislikes nos darán una muy buena idea de cómo se desempeña el video una vez en la plataforma. El número de vistas y sus respectivos comentarios afirmarán si este video está volviéndose popular.

# %% [markdown]
# # <font color='midnightblue'> 5. Definición de Hipótesis y Supuestos

# %% [markdown]
# > ###  <font color='midnightblue'> Hipótesis
# >> Con base en los datos reales, nuestra primera **Hipótesis** es que la categoría de video no tiene inferencia en los estadísticos/resultados del video.
#
# >> La segunda, es que existe una cierta dependencia entre los nodos o variables que decidimos analizar, por lo que gracias a esto es posible obtener aproximados de unos a partir de otros.
#
# > ###  <font color='midnightblue'> Supuestos
# >> - El número de suscriptores no influye en los resultados del video.
# >> - Los resultados de los videos no han sido modificados con algún tipo de bot/publicidad.
# >> - Se tomará las 3 categorías con mayor frecuencia como las más populares.

# %% [markdown]
# # <font color='midnightblue'>6. Obtención de la Base de Datos

# %% [markdown]
# > Las bases de datos se obtuvieron directamente del sitio Kaggle, son dos archivos .csv que contienen información sobre videos de YouTube México y YouTube Estados Unidos, esta información es representada en las siguientes categorías:
# - Número de Vistas
# - Número de Comentarios
# - Número de Likes
# - Número de Dislikes
# - Categoría de Video
#
# > Enlace al dataset: [YouTube Video Statistics](https://www.kaggle.com/datasnaek/youtube-new)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from time import time
from collections import Counter
from CDIN import CDIN as eda

# %%
mx = pd.read_csv('MXvideos.csv')
#us = pd.read_csv('USvideos.csv')
mx.shape #us.shape
# Out:
# (40451, 16)

# %%
mx.drop(['trending_date', 'title', 'channel_title', 'publish_time', 'tags', 'thumbnail_link', 'comments_disabled', 'ratings_disabled', 'video_error_or_removed', 'description'], inplace=True, axis=1)
#us.drop(['trending_date', 'title', 'channel_title', 'publish_time', 'tags', 'thumbnail_link', 'comments_disabled', 'ratings_disabled', 'video_error_or_removed', 'description'], inplace=True, axis=1)

# %%
#df = pd.merge(mx, us, how = 'outer')

# %%
mx.sort_values(by=['likes'], ascending = False)
# Out:
#           video_id  category_id      views    likes  dislikes  comment_count
# 35793  7C2z4GqqS5E           10   62796390  4470923    119053         905925
# 35646  7C2z4GqqS5E           10   62796390  4470923    119053         905925
# 35483  7C2z4GqqS5E           10   39349928  3880211     72709         692356
# 5261   FlsCjmMhFmw           24  100912384  2656698   1353667         682890
# 3871   6ZfuNTqbHE8           24   74789251  2444976     46173         330715
# ...            ...          ...        ...      ...       ...            ...
# 20986  1Dr0Mfy_Uic           29       4418        0         0              0
# 1067   1bqAMbitgHY           29      10979        0         0             19
# 21132  VfCa9Cp62iw           24       1592        0         0              0
# 21197  lGCjY1_Qqr0           22       5207        0         0              0
# 26609  T62wvYkc0cg           24     142036        0         0            155
#
# [40451 rows x 6 columns]

# %%
eda.dqr(mx)
# Out:
#                       Nombre data_types  missing_values  present_values  \
# video_id            video_id     object               0           40451
# category_id      category_id      int64               0           40451
# views                  views      int64               0           40451
# likes                  likes      int64               0           40451
# dislikes            dislikes      int64               0           40451
# comment_count  comment_count      int64               0           40451
#
#               unique_values     min          max
# video_id              33513  #NAME?  zzxLG6R5cHI
# category_id              16       1           43
# views                 35915     157    100912384
# likes                 14564       0      4470923
# dislikes               3693       0      1353667
# comment_count          6310       0       905925

# %%
print(mx[mx.duplicated(subset = ['video_id'])]) #mx[~] para mostrar opuesto
# Out:
#           video_id  category_id    views   likes  dislikes  comment_count
# 70          #NAME?           22    57070    6158       118            518
# 86          #NAME?           22     9409      24         2              3
# 219    _OXDcGPVAa4           26  1746221   93269      1792          10285
# 233    hcY52MFWMDM           25   263352     846       393            452
# 258         #NAME?           17   478507    1508       133            523
# ...            ...          ...      ...     ...       ...            ...
# 40419       #NAME?           24    13385     166         8             18
# 40420  WGOi_1XBclQ           10  4233617  436609     11240          56709
# 40426  TXTIMp7En-Q           25    78139    3118      1226           1896
# 40429  L6JFnZ5WabM           24   141734    5012       207           1294
# 40447  i7r_kMbyngk           25   121674    3558        58            491
#
# [6938 rows x 6 columns]

# %%
df = mx[~mx.duplicated(subset = ['video_id'])]

# %%
df
# Out:
#           video_id  category_id    views  likes  dislikes  comment_count
# 0      SbOwzAl9ZfQ           24   310130   4182       361           1836
# 1      klOV6Xh-DnI           22   104972    271       174            369
# 2      6L2ZF7Qzsbk           25   136064  10105       266            607
# 3      hcY52MFWMDM           25    96153    378       171            208
# 4      _OXDcGPVAa4           26   499965  57781       681           7428
# ...            ...          ...      ...    ...       ...            ...
# 40445  cHlzOeiJJQQ           27  4829416  20084      4796           1221
# 40446  r63VBOagGAo           17   653114  65639       547           3826
# 40448  _jnwjdMe3Zo           24    14067    538         6             90
# 40449  pAH9omNAWA4           22    22898     94        11              3
# 40450  dj5Z4jTE3-c           24   108936   5398       148            993
#
# [33513 rows x 6 columns]

# %%
df.sort_values(by=['likes'], ascending = False)
# Out:
#           video_id  category_id     views    likes  dislikes  comment_count
# 35483  7C2z4GqqS5E           10  39349928  3880211     72709         692356
# 2207   kTlv5_Bs8aw           10  13945717  2055217     23891         395562
# 21187  OK3GJ0WIQ8s           10  10695328  2050610     14718         387403
# 33126  p8npDG2ulKQ           10  10666323  1956282     13967         285604
# 3196   6ZfuNTqbHE8           24  37736281  1735975     21975         241247
# ...            ...          ...       ...      ...       ...            ...
# 26820  VQn4TyzEXuQ           22      4196        0         0             21
# 16455  VT3mYG36V9o           22     11662        0         0              0
# 31772  odC5kGG6phU           24     37594        0         0            108
# 16492  7HHbdjie9Sc           29     33499        0         0              8
# 16164  bMmVhI4u_sY           24      7391        0         0            140
#
# [33513 rows x 6 columns]

# %%
Counter(mx['video_id'])
# Out:
# Counter({'SbOwzAl9ZfQ': 2,
#          'klOV6Xh-DnI': 1,
#          '6L2ZF7Qzsbk': 2,
#          'hcY52MFWMDM': 2,
#          '_OXDcGPVAa4': 2,
#          'Q9kK6NWZR1U': 1,
#          'c9VTD3n_IDs': 2,
#          'XzULSsZYMRc': 1,
#          'uijjYNtl_UM': 1,
#          'cOJ68MQm2ac': 1,
#          'rZZEeeAVgog': 1,
#          'kTT472QeJGg': 1,
#          'yhdI98_O-Xc': 1,
#          '7jmJtdqI6YE': 2,
#          'Dhhp8M5K3UI': 1,
#          'M16Usa8oqDg': 2,
#          'OFXU_vrye9w': 1,
#          '238T-LaO_IM': 1,
#          'KO-QO5QQAyM': 2,
#          '7D-swI6qNLM': 1,
#          'WflHonz04Uc': 1,
#          'd1oYTRYmNHs': 1,
#          'GR1Af3ZG-lE': 1,
#          'y_6rR8yKONo': 1,
#          'Wi3nAYFigpQ': 1,
#          'nEAMm3nGxpM': 2,
#          '3RITF3vm-KE': 1,
#          '1i71glG1P5s': 1,
#          '6YHkNTRMUL8': 1,
#          '1ZAPwfrtAFY': 1,
#          'VVHWFZqV_mU': 1,
#          'O1v0F5-Xv68': 1,
#          'RkTi5_hu-kY': 1,
#          'AvIh646qPg8': 1,
#          'b_U9i0vSZnQ': 1,
#          'GZGdFRttWDI': 2,
#          'lHJLYWwzphw': 1,
#          '0zYvsH3IzTw': 1,
#          'cgYhR-3QfhM': 1,
#          'N5Ss8TbYnec': 1,
#          'RQMvpa4V2hM': 1,
#          'cU2FFwy0eKI': 1,
#          'cTRJYA6dibU': 1,
#          'O_jDNNEvvJo': 1,
#          'sBmvgi-gd2M': 1,
#          'eyskwaltDLs': 1,
#          'p-EupRWaX9E': 1,
#          'vawBoPTwFeY': 1,
#          'Mr2G7PcfXis': 1,
#          '9w6dJzxsDD8': 1,
#          'FhuxIRzs8LE': 1,
#          'S9qll04y4iw': 1,
#          'zexzfD25jWU': 1,
#          'kzwfHumJyYc': 1,
#          'so0ccfs-psI': 1,
#          'tU3b7GVb65E': 1,
#          'mevdRfjbwH4': 1,
#          '#NAME?': 516,
#          'zR-9Pf-BBrM': 1,
#          'J5sgeaTui0w': 1,
#          'XDqZ57zAsGY': 1,
#          'M4W-nrYGRYc': 1,
#          'ag3qaxX6lW0': 1,
#          'ZIf-yocPdKM': 2,
#          '8_MFaKfSZUI': 1,
#          '0k6gGxwNFSI': 1,
#          'qlHi7uhZdvU': 1,
#          'mXmLxLCs9HA': 1,
#          'YxJB396gmWQ': 1,
#          '3VDJQMaSWF0': 1,
#          '5Dimg9RM4Lo': 1,
#          '5E4ZBSInqUU': 1,
#          'OIBG99riACs': 1,
#          's-VstUmpPzM': 1,
#          'URnaV-AK4og': 1,
#          'IZRJsmfscIg': 1,
#          'y5wvD7QH1x4': 1,
#          'IBd5v-MPEH4': 1,
#          'bbFsQ3QuJAc': 1,
#          '3JMZx99Yb_0': 1,
#          'XcjFWrzjLPE': 1,
#          'DHt9_TXbKbI': 2,
#          '8DLQNl20YE8': 1,
#          'LT4qAHRqrjU': 1,
#          'Dt3i0xvLW_Q': 1,
#          'OlKxqYmZNrc': 1,
#          'qxyJYWGf57k': 1,
#          'P3q93hzUGEA': 1,
#          'QzlD0W4J8mk': 2,
#          'uUUd_8Gl6Bk': 1,
#          'qh3Vr7x_5bQ': 1,
#          'nOVd0sNNjc8': 1,
#          '17bOlbDNjmk': 1,
#          'nC0TkydzQM4': 1,
#          'LTiiX8hq4Sw': 1,
#          '_GaoLGcZ8Wg': 1,
#          '2-p6XmtKCVY': 1,
#          'Yoa0Yqjedhk': 1,
#          'Rwlubt8S8MI': 1,
#          'p8smIhAsI6g': 1,
#          'szAR--Hdtn0': 1,
#          '62uv76jjUG8': 1,
#          'fCOYUfEvxcE': 1,
#          'nho5bnPE8qY': 1,
#          '2kyS6SvSYSE': 1,
#          'FEp_keCj6kA': 1,
#          '8SmKYBgDTVA': 1,
#          'jXndHBU_tq8': 1,
#          'YnQoEHHM_xc': 1,
#          'ExbVoHLXPzg': 1,
#          'eYcP7ItiHHI': 1,
#          's_kRjjlGCcQ': 1,
#          'oFy58DC4Evk': 1,
#          'of1vkf-Mxuk': 1,
#          'zw26qBC32lQ': 1,
#          'of5k7eEtE6c': 1,
#          'rl87CstffpE': 1,
#          'pCzGf2FYn4E': 1,
#          'vl8yv7kTTWI': 1,
#          'G2LKPsoc24k': 1,
#          'ehaaxAyRf18': 1,
#          'A106_JEPWm4': 1,
#          '4DnWZQTytXo': 1,
#          '1q41CjSKa7s': 1,
#          '1wF68X7X768': 1,
#          'vDiN9657pNM': 1,
#          'K7i1BHg8yjc': 1,
#          '4cTYebG13fQ': 1,
#          'ch2bHvup3p0': 1,
#          'a9NZ4nWdjfM': 1,
#          'lELY0_ZrPMg': 1,
#          '064HDEJjPHg': 1,
#          'rm6Y60BmLa0': 1,
#          '0HCufSLOeE4': 1,
#          'BVJzVZ-gnA4': 1,
#          '0dBIkQ4Mz1M': 1,
#          '8V5h1ZaOK8A': 1,
#          'JxrEs0ZeU44': 1,
#          'SOFXq2cenSI': 1,
#          '5Dprb5g-6_g': 1,
#          'rFNCO_VRaEk': 1,
#          '7v8sd_Bar-w': 1,
#          'mx9IrngKvfg': 1,
#          'VvsVDp0aYHY': 1,
#          'sX2qEhu97p8': 1,
#          'X_vSOhNshg8': 1,
#          'l5jL10riBtc': 1,
#          'HXoUb9ink6M': 1,
#          'UJC-hJbmlNA': 1,
#          '3xiFKybX2RI': 1,
#          'vV-F3sY34u4': 1,
#          '3s1rvMFUweQ': 1,
#          '0s12_01FIko': 1,
#          'V0VCNyvc9Mk': 1,
#          'WI5MSR8BgXE': 1,
#          'zPn6Kl-RIkQ': 1,
#          'KXb58FyoIa4': 1,
#          '_xMcC2uIseE': 1,
#          'hs6aBUAbTWc': 1,
#          'vmCjs1ZGpdw': 1,
#          'sAOqENI8p9Q': 1,
#          'o8_gcXkd8EM': 1,
#          'gvvLino2tNY': 1,
#          'dAHb2GDx6ok': 1,
#          'mB7DwV9zRzg': 1,
#          '-7K9G4eWzJc': 1,
#          'ajBkZfW0nUQ': 1,
#          'x-qhQespWm0': 1,
#          '7kvjzw0AQY0': 1,
#          'L8DnWMqtxjE': 1,
#          'mvFGr9q0vss': 1,
#          '0yIWz1XEeyc': 1,
#          'O9g-hqEnfUo': 1,
#          'd9ndEyk2lBw': 1,
#          '0pNCxK0Hdl8': 1,
#          'JzCsM1vtn78': 1,
#          'Dx7S34lNt6A': 1,
#          'QSwlPz3ruYA': 1,
#          'Nfd31XfFZ94': 1,
#          'jRl689eyaWg': 1,
#          'Zw5jzd4BvBY': 1,
#          'PpvzVcnICJo': 1,
#          'Ttqo0pFoAAM': 1,
#          'RtPf3dHF8uM': 1,
#          'xQW3-CeUV2c': 1,
#          'dTuYRCf-G1E': 1,
#          'MGeSKdq1V20': 1,
#          'Mwsy6T99j04': 1,
#          '5qpjK5DgCt4': 1,
#          'CZCQH6DGX3w': 1,
#          'i0TXj8cjVfs': 1,
#          'hcuAuv-kkyg': 1,
#          '_0FiEmKkIHU': 1,
#          'e_XgSU1X4Ms': 1,
#          '7J44ynoFWSk': 1,
#          'jAdVVPw3Sao': 1,
#          'Nr3AuidaiSo': 1,
#          '5dCjl2efnyQ': 1,
#          'W-4d6rdrg3E': 2,
#          'eAlsZp9S5x0': 2,
#          'DqiMJ6dAtC8': 2,
#          '_4nBM09BSEI': 2,
#          'RyEZQV9CwAM': 2,
#          'RyMVtv5wCIU': 2,
#          'o7jUddH52JY': 1,
#          't7cL_jDyuUI': 1,
#          'Nr-EpdBWeCE': 1,
#          'IBRok8hS72o': 2,
#          'BUdI6ot2j-8': 1,
#          '6mux5Q9AGfE': 1,
#          'SWhfMrcS9eM': 1,
#          'eBaYLHNmlLs': 2,
#          'ce2GdkBgYaE': 2,
#          'Y_r7bvUt-YM': 1,
#          'KMXIKSi96LY': 2,
#          'VQXfLFWhKRo': 1,
#          'QuSEbo03fc4': 2,
#          'oPD8Z07zK4U': 1,
#          'cnOrjcG_Sxo': 1,
#          '1GYQSPvoYww': 1,
#          '4wiO5sGTHxg': 1,
#          'Q2XDusl1wR4': 2,
#          'ZMxnWZktTRA': 1,
#          'lI8TfgG2k6Y': 1,
#          '50jQol_-2dM': 2,
#          'XhquqP9xSrI': 1,
#          'r1DvFVEL9As': 2,
#          'fSZC1S0JpJM': 1,
#          'ok4tCywAlXc': 1,
#          'sB1btJg17Sg': 1,
#          'Lz58Ch1VnR8': 1,
#          'k6F_JlX6LKg': 1,
#          'e7RcwQWSngE': 1,
#          'HIUJFnY9ILE': 2,
#          'YaLmzawRjlk': 1,
#          'iaoieyQ749w': 1,
#          'lfWfef1z3Yc': 2,
#          'b6X9vE4CzMU': 1,
#          'Ehke7aPI9l0': 2,
#          'KFz_JBteACQ': 1,
#          'DcTZilYN_1g': 1,
#          'Y4nEk2Y8HfY': 1,
#          'oyvN5ExU4fE': 1,
#          'm7e3Yfc-N6k': 1,
#          'AS-J_xhmwWg': 2,
#          'f29C4nLLvLQ': 1,
#          'tsMw-VMUtNU': 1,
#          'rEexgn24Zd0': 2,
#          'VHk0NJJYK2U': 1,
#          'YCQEo_2f5SU': 1,
#          '084uZsxEAIU': 1,
#          'Grjf061dV4w': 3,
#          'htC3S04x4zw': 1,
#          'cwMGtzZrr1g': 1,
#          'Cy6U9rlxXNo': 1,
#          'ZIQIYOvn0t0': 1,
#          'EnBfzD0HhtM': 2,
#          '3W9uwoM3WAc': 1,
#          '5nEogChRGE8': 1,
#          'NPi7GUNVMoM': 1,
#          'VsYmwBOYfW8': 1,
#          'j64xl7m8HhE': 1,
#          'ERI3RDsmkQM': 1,
#          'ok4BV_EdMyY': 1,
#          'xo6EcR8xvFM': 2,
#          'IMOmpTtlmWU': 1,
#          'FCU3WcPG-2U': 1,
#          'hYxAT-574tE': 1,
#          '-78WxK0q2v4': 1,
#          '7GWXGqjSUJU': 1,
#          'cJUEwuoO2dA': 1,
#          'Z77YtiJAFyU': 1,
#          'uQ4CX91GWnw': 1,
#          'GX9gZ4qh4v0': 1,
#          '2z0h1BOX4c0': 1,
#          'DhiYw8DYuZA': 1,
#          'Xc0V4S17T4I': 1,
#          'RS6dEL5VIr0': 1,
#          'Ax1P5Q8Kr9g': 1,
#          'IwGjXDFC8kE': 1,
#          've3oQBjcAGI': 1,
#          'qZ86rzeT9JY': 1,
#          'jGXRidkmKNI': 1,
#          'mqOgU3uJUUE': 1,
#          'mbJ2wInVSyY': 2,
#          't2wv7Etl0vc': 1,
#          'Rb8_EdTYjXI': 2,
#          'vRXIKBfJp5c': 1,
#          'BKHpi93sQOY': 1,
#          'Wg2DYxo-Pow': 1,
#          'NJMWETuxVic': 1,
#          '0n05ezCsczI': 1,
#          'AWqYXzvT4OM': 1,
#          'gF8sd2BQwoU': 1,
#          'gHruDCvE93k': 2,
#          '744FHFygxiI': 1,
#          '1TUwj5r8MZQ': 1,
#          'Mawjza3psiY': 1,
#          'XLWjmAN2SLo': 1,
#          'fPYffm4nIYA': 1,
#          'Nnc362avOtM': 1,
#          'zASfdpG8UqU': 1,
#          '18POj5UkGRo': 1,
#          'Qu0YhyzBB6A': 1,
#          'm7cRGq35eK8': 1,
#          'rYts-vQmlZk': 1,
#          'v9nEWtEdkmc': 1,
#          'PVVFOXUZObQ': 1,
#          'yoeHU8qaewE': 1,
#          'asvHEW9v2WI': 1,
#          'UO4ZYiqVkN0': 1,
#          '0CkkoaLSCtw': 1,
#          '9O9XvEWWjOk': 1,
#          'oGSNSLD8rcw': 1,
#          'ORn38gU3zAc': 1,
#          'Ega4GZhszPs': 1,
#          'RqccSEEO-5M': 2,
#          'znAe-yoVvA4': 1,
#          'iEc-Qi1KJ0Q': 1,
#          'iBU3wxHzEHA': 1,
#          'zgM6-41jzuo': 1,
#          'vFI-kU_Hb38': 1,
#          'n9uXUiBPPPY': 1,
#          'tOwTdl-CR7o': 1,
#          '9519Irf1W20': 1,
#          'sJ1Drsk7Cfc': 1,
#          'C7R39aVhQuA': 1,
#          '77o299p5dFw': 1,
#          '9yPJRctSJB4': 1,
#          'B7Vp_0qLIPg': 1,
#          '4HrqAdtHsvY': 1,
#          'y0yyOekGQqE': 1,
#          'N_xJgJNcRzk': 1,
#          'N0dGdT80fsU': 1,
#          'XSjvqLN15fE': 1,
#          '6TAUjQerS5M': 2,
#          'XStpREMS8Fw': 1,
#          'l1dQZ-dDZRk': 1,
#          'CtBca6H6Teg': 1,
#          'jQUk4bzyxkw': 1,
#          'JVcOZdS0RFU': 1,
#          'qXftNTBdEog': 1,
#          'WnUrVKTnPWc': 1,
#          'gjXrm2Q-te4': 1,
#          'w9nThMKhmys': 1,
#          'UCoMgd1vDe4': 1,
#          'mRydIvA6fDM': 1,
#          'W5Xn11roRcE': 1,
#          'lV-5FiVde-s': 1,
#          'b-ShNqtj8Yw': 1,
#          'zsLAf-Dn7Wk': 1,
#          'xNZ50VgYArQ': 1,
#          'eBft4vEcuoQ': 1,
#          'Ldt3QLqj0UI': 1,
#          'pA7-syt_0dc': 1,
#          'U9LAm3on8KQ': 1,
#          'RojGF6fwE-U': 1,
#          'QKcc9EGj7g8': 1,
#          'aB_7Og-sYCw': 1,
#          'xqJmV8QcW-g': 1,
#          '7zNsSDUAoTw': 1,
#          '3hy5shfK4Ac': 1,
#          'aGY4nyjAdyM': 1,
#          '-50iGYl_VD0': 1,
#          'Wmn7cYCeUGM': 1,
#          'KUdJjEkVHk8': 1,
#          'YPeKjFV1-ac': 1,
#          '2wZmRK_bt7k': 1,
#          'dqMGDmIIusg': 1,
#          'KJ_9T51VZb8': 1,
#          'oo40Wd_Z0wA': 1,
#          'vcEjcgB9OCo': 1,
#          'rKZEjgSC52M': 1,
#          'ApAAdA5pZzU': 1,
#          '76ZV5I0vqkE': 1,
#          'o6Qj8FgmgXU': 2,
#          '8YY36IUmQ8c': 1,
#          '5AppiAWjR30': 1,
#          'Z3lhrL3qo_o': 1,
#          '1g3u3AyEZ8o': 1,
#          '7X2HOaQSGac': 1,
#          'irfxThagxy0': 1,
#          'rKtWh732n1c': 2,
#          '8vdmh6BUz7g': 1,
#          '8-Cjsnq8kVU': 3,
#          'fo9610Cj3k4': 2,
#          'EBKz0E6i_vc': 3,
#          'OzH56jsQ3p8': 1,
#          'i8_GlmNP0h4': 1,
#          '54Q6TpcPxj8': 2,
#          'dul_EuolX8w': 2,
#          'vUKRhDKBV-s': 3,
#          'MnF2ddTz95U': 2,
#          'hHGOdHbLlU0': 2,
#          'AtPmhHaDtKw': 3,
#          'r18pMV8ElDs': 1,
#          'ozztqm3plJo': 2,
#          'yCWqnxYEDmE': 1,
#          'SB3PV7OIWiw': 2,
#          'L7vMtX7No0g': 1,
#          'AKHdQVpRkCU': 1,
#          'Sqluv4O2uyo': 1,
#          '7GLskOxW4ns': 1,
#          'fZxv0m3QQrU': 2,
#          'pq4SNvzfI7I': 1,
#          'JsHgnyS7Glk': 1,
#          '5n-t96K9GeA': 1,
#          'i0VF6Nl2qhM': 2,
#          'xzpQSINtLkw': 2,
#          'Y8-A5TpaI8w': 1,
#          'AeMPTuEGv1E': 3,
#          'moR8vvRSLuI': 2,
#          'Tih7m8k0GC8': 1,
#          'uYfTV5ujZ2k': 1,
#          '8CAg0yvPDpI': 1,
#          'aEQ81NxuSk0': 2,
#          'qYrQRjKtRYc': 1,
#          '1YEXXIWqkMM': 1,
#          'pzECFazgfUo': 1,
#          'm0YboXTRjkU': 1,
#          '2ZakeOsieKw': 1,
#          'qjXOFVlihj8': 1,
#          'TDcyviHSN1E': 1,
#          '0gwkMY-mzUQ': 1,
#          'J24X3qxeFRQ': 1,
#          'egdeKCqA0Ck': 1,
#          'MCPZHTdfWJk': 1,
#          '6ns6QKvYB5A': 1,
#          'JuUba6Pphbc': 2,
#          'BrbqKWLSt10': 1,
#          'NzD354q8MeA': 2,
#          'MA0g3Chb5Bo': 1,
#          '9-R54dDfRcY': 1,
#          'vDsDg7iuT-A': 1,
#          'VxGjjWNcPWE': 1,
#          'KoKnNggaTZY': 2,
#          '1kv7f9eZXBA': 1,
#          'fP3xTYGHZJA': 1,
#          'T9Evjw09woU': 1,
#          'Nw9wMgE7s3U': 2,
#          'hW0iRpvZ88E': 1,
#          '7KBf_SPeHl0': 1,
#          'Uy2YKotRThk': 1,
#          'wgZv-ELzgn8': 1,
#          'qMRIOecBxpE': 1,
#          'WyWdQfJ6uSo': 1,
#          '_uYTvUAnLWM': 1,
#          'hz7335YtmFU': 1,
#          'g0dWLIbG1_g': 1,
#          'xM8YD9ZJvKs': 1,
#          'BBMERzpEe-k': 1,
#          'rHkXhlBzRr4': 2,
#          '5B7bCn6EZqU': 1,
#          'oQALGtoqI2c': 1,
#          'Vre0wdYG2Is': 1,
#          '9sJtfCOjBwg': 1,
#          's2y3z7IsCqY': 1,
#          'Jkcun4KNiRk': 1,
#          '7a1lcw9O5gQ': 1,
#          '4rLHNsOXVDo': 1,
#          'GegDJ0zYeWg': 1,
#          'oa-WPEBVBz4': 1,
#          'OGdLNNp0e3E': 1,
#          'mGQ4C_UfyDM': 2,
#          'jpyMlH6Izvc': 1,
#          'Ru0Ws2_y3Bs': 1,
#          'zZiIUMy-ERc': 2,
#          'XgwjVGadwns': 1,
#          '0apRfQ2mjkQ': 1,
#          'f-_mmbKY910': 1,
#          '_WBOghYG8wo': 1,
#          'CPjMb4zfByw': 1,
#          'tBhy1C2JtvU': 1,
#          'r95_QLPoCY4': 1,
#          'n7PCZ8oVCz4': 1,
#          'pCff9BD8YuY': 1,
#          '1Zj2HUTY-aY': 1,
#          'GU3NHhkgfpc': 1,
#          '3RhwURUXFq8': 1,
#          'KoE5lHfLwos': 1,
#          '1wenw53Dkro': 1,
#          'bP_PugqKiKo': 2,
#          'RW88KOezzkc': 1,
#          'P3nYOK_vM9U': 1,
#          'To2GTNVohEs': 1,
#          '3MXsBF3rbhU': 1,
#          'jSdreTP7z24': 1,
#          'NQRigANzrVI': 1,
#          'E0r9H-uiIbs': 1,
#          'ZJQJWumrsAA': 1,
#          '6MIf8Z1QGNM': 1,
#          'UfvqYdDGKak': 1,
#          'chR7iFOdV00': 1,
#          '4ElbjzSg4KY': 1,
#          'PFJfyci60kI': 1,
#          'h4c3gmVxy6s': 1,
#          'ZEYMIMgPCQY': 1,
#          'iYrsah3teSY': 1,
#          'lNPeuNMgBZM': 1,
#          'KPV4Pac3muA': 1,
#          'lVJ5Bm2uQxA': 1,
#          '8hKbIhrb1WU': 1,
#          'VwZuo1EBdxw': 1,
#          'ZJHodorwPUs': 1,
#          'wxrkhPhRa4A': 1,
#          'U_3Op0bQtZk': 1,
#          'wAXAixs2teA': 1,
#          '1dSHVh3FYfg': 1,
#          '9ln8DAn28Bg': 1,
#          'tTtuVmLbzjE': 1,
#          'byyrD0yjKb8': 1,
#          'G-pSkCXbBWY': 1,
#          'H-FiZfmqfes': 1,
#          'OV9n85JDEK8': 1,
#          'sottGW1p5os': 1,
#          '68MEzM3TbuA': 1,
#          'nGrmXOg0Lek': 1,
#          'baIWnZdDtUM': 1,
#          'aVnoTmZiq0o': 1,
#          'NTYG3ozrG2Q': 1,
#          'B1tQ389S0wI': 1,
#          'kcTlLlhc9_I': 1,
#          'PS5XJ19ME-s': 1,
#          'Sm9EB4lDQA4': 1,
#          'nvHFFbCHMLU': 1,
#          'tTpGUkNYyZ0': 1,
#          'KZpB9fWXDvQ': 1,
#          'I8WFHK3jHyc': 3,
#          'OC4GTCT2kDo': 1,
#          'JKsKsVx9IFQ': 1,
#          '4HcZ3mBPmOQ': 1,
#          'N8yGEfUaX10': 1,
#          'AtJtyj7_BxU': 1,
#          'b2s2vegP1Eo': 1,
#          '6dUMVRRnwe4': 1,
#          'lnugLV6TSBM': 1,
#          'cFyzucqhWgQ': 1,
#          'LL8rruyTyCw': 1,
#          'y1YVencIN3o': 1,
#          'Gs-FV8GhBQU': 1,
#          'lYWnBUiNHak': 1,
#          'Y9QsjZYRdes': 1,
#          'llU3o-ElhPE': 1,
#          'LDzBX_zj9hg': 2,
#          'gy82G0titRA': 1,
#          '5pFI3-Ut6t0': 1,
#          'MsRWkjuhblg': 1,
#          'WjI8jMjUnTM': 1,
#          'yBJ8uFP0h9I': 1,
#          'tv4AWootLQw': 1,
#          'gH777GgPKFY': 1,
#          'lAC_TrzR3EE': 1,
#          'wl1Jl_So7Ns': 1,
#          'supiogUqVpY': 3,
#          'L-kalEFn8Ms': 2,
#          '1S4sO3BOfWY': 2,
#          'uexYI3kVUrE': 3,
#          'veKCW6QPLUU': 2,
#          'n1E5YukqRQ8': 1,
#          'M9tvMPF07wQ': 1,
#          'h_aS4lFpG08': 1,
#          '2lMIS32YepU': 1,
#          'EFoTzUEG_V4': 1,
#          'IPOAJA4begI': 2,
#          'ixxR3ZoqnF0': 1,
#          '67JcaXD1h5w': 1,
#          'J6ppQs_A-nI': 1,
#          'PwervJzDYYI': 1,
#          '4Srf4QCobpI': 1,
#          'syJ2i4Uz42o': 2,
#          'CkM_ATMt32M': 1,
#          'hM23vXlT_VY': 1,
#          'Z1erSu_ikO0': 2,
#          '8obOOQG_kQA': 2,
#          'HiNOTFt2POI': 1,
#          'nTME7i01lb4': 1,
#          'TyHvyGVs42U': 4,
#          'Pfu8ayVMEjE': 1,
#          '9TqIrdDPqSs': 2,
#          '43i6ULPnh9M': 1,
#          'K5HhHzec4cg': 1,
#          'sdmDHOiYEgA': 1,
#          'Hxi3b7KnO5Q': 2,
#          'xPbC25UNi68': 1,
#          'iJAa3MbK1Eo': 1,
#          '1sHrQoyTYi4': 1,
#          'i9GSF3ROa58': 2,
#          'HU_hbX0hD2s': 1,
#          'fQ4-aUIbff8': 1,
#          '1NhedxVMVms': 2,
#          'QiTKwMIQt30': 1,
#          'GADyZGqelyY': 1,
#          'Tn4HjEJ4ZCs': 2,
#          'sX123gohl9E': 1,
#          'IoARH8nJluc': 1,
#          'IBA4T0kMEV8': 1,
#          'hAEsTQk5_3Y': 1,
#          'GkskGWrIq0g': 1,
#          'beK18BLR8bY': 1,
#          'p8XP7A7kvzM': 1,
#          'YOyubtH2jOs': 1,
#          'i8FmC23jS_k': 1,
#          'lJO9sDSJ5Bg': 1,
#          'gui0XPvlvRE': 2,
#          '5m4UlI97dNE': 1,
#          'e3yJPSWxk5E': 1,
#          'VAXurTKlZlo': 1,
#          '0el0qa5Gz1w': 1,
#          'RX2EyrCi6Yo': 1,
#          '5-W66g0LBvc': 1,
#          'uSc1O3SduqY': 1,
#          '3L27ILCI1DA': 1,
#          'oZWfGX_xKcg': 1,
#          'ssVrzoCgr_w': 1,
#          '1P5R2En8PvQ': 1,
#          'euDb2CxSHPU': 1,
#          'vVioMPhM3NE': 1,
#          'd6qcFVRCiqE': 1,
#          'vdXex2xZgNQ': 1,
#          'VhDAf_cjT3I': 1,
#          'DOscaqaujV8': 1,
#          'IFtFzBIPBFo': 1,
#          'RCWFVTzPA8k': 1,
#          'LTzx6feeX9w': 2,
#          'jKkOYEW7RvQ': 1,
#          '5tHyEZvqbpE': 1,
#          'VYxWvXCfG_o': 1,
#          'QQ3_BFqTrLc': 1,
#          'ZymQQdpo3do': 3,
#          'D-dwmYeLLng': 1,
#          'e7n1wiuVlD0': 1,
#          'FpPJ77Gj4QY': 1,
#          'wLL1VEuwmw8': 1,
#          'uDocKL4WRQE': 1,
#          'ub17n7FvyLQ': 1,
#          'tJsiLM88ZWs': 1,
#          'fRj34o4hN4I': 1,
#          'Dp6PVAeUEh4': 2,
#          '15pHWNYed4c': 1,
#          'IBLVSxcWqNI': 1,
#          'UcrQNsHjFJY': 1,
#          'Pz27VpzJTLg': 1,
#          'gOkkrN3H8Nw': 2,
#          'aKopiJ5-RZY': 1,
#          'GsZ7-5oWg4s': 1,
#          'b8DBtOfixgI': 1,
#          'cVTIB-qedDA': 1,
#          'j0SPBv_3NdE': 1,
#          'FMGMH3HnVu0': 1,
#          'sGI8qPK7mBg': 1,
#          'coOKvrsmQiI': 1,
#          'ZwglRbc6rkI': 1,
#          'FuWwwKT8PF4': 1,
#          'quX6kr0InYQ': 1,
#          'XLR81PJ9FWI': 1,
#          '32ybRpQUl5w': 1,
#          '0fJYGIUhwkM': 1,
#          'W6PCTYvFfXE': 1,
#          '7tMQj8r5dtY': 1,
#          'MQCqMWEqJb4': 1,
#          'EqEmrrbOKgk': 1,
#          'khdXA2WacpE': 1,
#          '2TREHAq7QAk': 1,
#          'YNIxoOxPGWA': 1,
#          '0ZyXb7VqXjg': 1,
#          'KstndSY3_-s': 1,
#          '1hOzMtzFwg0': 1,
#          'hKNNCofEehE': 1,
#          'KoCCiKcNSl8': 1,
#          'KnpmZkWmZfc': 1,
#          'Vc5yRwRjq9o': 1,
#          'lBI5-SXIut0': 1,
#          'kJqZ6cGZWRE': 1,
#          'qilpG6wySdI': 1,
#          'Q_FAO1ZNKgo': 1,
#          'b3g-d4vDfRk': 1,
#          'pM8U7ESZwFg': 1,
#          'oIS1_zHeqp4': 1,
#          '0z9_SB6NT8Y': 2,
#          'Ev43_5xTXAk': 1,
#          'WSggcKscf5g': 1,
#          '7eUNPdrbYbY': 1,
#          'zzUYpmEyuMI': 1,
#          '24PSvTn3hqU': 1,
#          'ZKIAw0kxIcg': 1,
#          'yHGSR2OTnPU': 1,
#          'YWnEddq90Xk': 1,
#          'rVEHCs9jwyI': 1,
#          'wj2YwjnhyWE': 1,
#          'M0q0JgQo6IA': 1,
#          '9Ms_hGvFfJg': 1,
#          'KesQmDU-hXc': 1,
#          'XgGkM3igrtk': 1,
#          'iCj34Kn0p3s': 1,
#          'KrQckuhoe4E': 1,
#          'RTSqlAIX0to': 1,
#          'Jn7tf1eKaFg': 1,
#          'GzbhbNkTIDo': 1,
#          'Ee2bJwgDV1g': 1,
#          '7IZlPSI5Vrg': 1,
#          'xhLReQ_vUb4': 1,
#          'FbKucqSr55I': 1,
#          'j5cMeBlrj6Y': 1,
#          'hORij5-p9Y8': 1,
#          'OLNn1OuZr6Q': 1,
#          '7Q59auc8ctE': 1,
#          'osqqrV3bY-0': 1,
#          'sFcbhEh5ujA': 1,
#          'sQB2NjhJHvY': 1,
#          'kMqjpmZe7pI': 1,
#          '02y2zz0jYG8': 1,
#          '8By7qogzE3g': 1,
#          'g-2vfzNECVI': 1,
#          'msvVibUovfU': 1,
#          'P7MJnELbCIk': 1,
#          'j1zt-EZzSMc': 1,
#          'lLjifWlf4wc': 1,
#          'bgSpCJCxUg0': 1,
#          'QHPJRAyynFY': 1,
#          'y-XXscu_q_k': 1,
#          '1st_Bgvw7OQ': 1,
#          'JUi77D5wkJk': 1,
#          'eUbgosTE2Is': 1,
#          'uXT3f5nsJQA': 3,
#          'nLyCJQJ0Nds': 2,
#          'cf_NolK_bns': 3,
#          '1DXVXF3PZ8Y': 2,
#          'IIurzx12GeA': 1,
#          'qW1Q8IaaRto': 2,
#          '8Eokgoc91iY': 2,
#          'VBiz1MDcdAI': 2,
#          'HnEkf5t0ghU': 2,
#          'ZAqTdzq7qX8': 2,
#          'w8vsuOXZBXc': 2,
#          'XOTUMEgJDag': 2,
#          'L_vwZ9HUfyQ': 2,
#          '6GuJz9len-U': 2,
#          '5wuq08B4u_U': 1,
#          'oDmblhAq3Cw': 2,
#          'g69IvDmWHis': 3,
#          'xsu0VodjA3s': 2,
#          '1C53hgijnyM': 2,
#          'tfiuE9_rvhQ': 2,
#          'FlorHemr3SI': 1,
#          'V9YuziDCXtA': 2,
#          'IcdRQy-lJN4': 2,
#          '3TxcNH2psoM': 1,
#          'lwz1WU77hl0': 2,
#          'wf36jZxnbCk': 1,
#          'w-Ksq3W6QHg': 2,
#          'aM3_pMIqs3A': 2,
#          '23GZcpr3Fqk': 2,
#          '3n4_AWqo91Y': 2,
#          'YeZpbuzNKWs': 1,
#          'ImeRo3WWQSM': 2,
#          '4SRzzWr2414': 1,
#          'K8hU3PxDGY8': 3,
#          '17iQpD35kOg': 1,
#          'IRHwhISJVcQ': 1,
#          'R4UBL2BNz_E': 2,
#          'w95SgWoUnuU': 2,
#          'ENYEdLtVYGM': 1,
#          'GeJ9BVn54os': 2,
#          'mY9VJF7G6Ic': 1,
#          'TmWypJ08m9s': 1,
#          'mE2zJlvS7I8': 1,
#          'q_x8oIOg7Lk': 1,
#          '1fWXOLsoYGY': 2,
#          'Sb5Vgs5_JtU': 1,
#          'OfyqaByT-qg': 1,
#          '4n0Zx7Ir51Y': 1,
#          'GS_Efh8ziU4': 1,
#          'LLeLTaELb4A': 2,
#          'XH5ZKbStN2M': 2,
#          'yKR9tT331Og': 1,
#          '6NSxERaXFCU': 1,
#          'E8VdmNUUrMU': 1,
#          'uhtDQZgraEs': 1,
#          'vGMJVLruFao': 1,
#          'Decjbm6wWcA': 1,
#          'l7LyWLsHnL8': 2,
#          'kPlSKissT40': 1,
#          'AwHB1xzk_Pg': 1,
#          '_PjS_oYWWmU': 1,
#          'k9u7fIeXagY': 1,
#          '3Bjh45wlBC4': 1,
#          'DaGBRW4oh0g': 1,
#          'cIU0vSdm_iQ': 1,
#          'PvQ8MdvtJUQ': 1,
#          'q0sc0MNZ--k': 1,
#          'JyWjDs2Um7w': 1,
#          'XspHC1QLYqk': 2,
#          'Esj5PEDNWkU': 1,
#          'DTtH2skqFPc': 1,
#          '_FbHQCib-uM': 1,
#          '491bxO8tgSI': 1,
#          'Z8G4d-94jBw': 1,
#          'eiuNHYV13Wk': 1,
#          'VRX0_O1VavE': 1,
#          'Ov2mIPI9JuQ': 1,
#          'dRQKwuuQqEc': 1,
#          '0eNOvOzOkhI': 1,
#          'Y_Tki7QekZw': 1,
#          'T1tZwQJWrYY': 1,
#          'noka40W4_Ck': 1,
#          'osBXauHQ5Yg': 1,
#          'eWhpTWkUpIU': 1,
#          'qAxVrtXDcm4': 1,
#          'AtitIdK4v2k': 1,
#          '_z8PV7manxI': 1,
#          'zz4q3jmDFZc': 1,
#          'QYutQB6qSSc': 1,
#          'NdnEZnXfEPU': 1,
#          'iffCGJDS2uE': 2,
#          'W-4p-NqoTvA': 1,
#          'RgzEk1LCeiE': 1,
#          'TVZ_MozAwfQ': 1,
#          'IOwWJmrjfhg': 1,
#          'lVwyz1x3zYk': 1,
#          '2R3yqYF8Nbk': 1,
#          'zIJJIjDvrT4': 1,
#          'pGECQPRnRTQ': 1,
#          'p9WjUsuWW5M': 1,
#          'y_FD61fVI8k': 1,
#          'WF4VzRZ1pZk': 1,
#          'xUv_5_m1jOA': 1,
#          'fZySW-I-yRY': 1,
#          '9Mjmy1U0iPk': 1,
#          'L2BjgRorp9s': 1,
#          'LVPjn_XYxxc': 1,
#          'g0SXTNYKDUE': 1,
#          '_KBsV-_Rg34': 1,
#          'CZyHA5uAMEQ': 1,
#          'eiGrNlimmZc': 1,
#          'rXhHXAz0moY': 1,
#          'ulgG4tqRk7s': 1,
#          'HabUsbff5aY': 2,
#          'Y2y5Z7i4M2I': 1,
#          'MB0_Q46cGe8': 1,
#          'VZIrg0vdYGM': 1,
#          'cxJfj1y1JX4': 1,
#          'UtLXSM4WUIw': 1,
#          'mwkkzqyYBLw': 1,
#          'CKgCiTQMxm4': 1,
#          'YgOu4AHs-UI': 1,
#          'NYIydgra2SQ': 1,
#          'cefeV-Aluec': 1,
#          'iEjAI8kOVEw': 1,
#          'Pqrsew3p4EE': 1,
#          'KMd1AT51La0': 1,
#          'pxk7LWuu1ps': 1,
#          'ZcPtLyaHQ6Y': 1,
#          'aY2yf-yhNmE': 1,
#          'XmELYApWmCk': 1,
#          '0yDkoj9Q2II': 1,
#          'oq9sPnLGLs8': 1,
#          'QrofqBYumVA': 1,
#          'eOQpjvnm4ME': 1,
#          'lUbhJmTa1tM': 1,
#          '9craEFMRXvs': 1,
#          '0ydrnmoGpP8': 1,
#          'bpnskwPdpZs': 1,
#          '2udY5jY9VKk': 1,
#          'AV60jjO8PN8': 1,
#          'BUS99d4NIHA': 1,
#          'fkeknO7L6Ho': 1,
#          'mEuItz-MKbk': 1,
#          'EKDI6d6x5gs': 2,
#          'elLyORLGEhs': 1,
#          'JIXHmVbkUkk': 1,
#          'c7X845hK5bE': 1,
#          'bvvEdZYngeA': 1,
#          'UL6xPiYvzS8': 1,
#          'BkqH4Q4jaSY': 1,
#          '7n51EoSBHtk': 1,
#          'd_Hf8XMghg4': 1,
#          'b4Ajm0tDmL4': 1,
#          '_qPd49Rsqs8': 1,
#          '6VI5_Qi908I': 1,
#          '4Q2JUxmU1BM': 2,
#          'OXRkj_WyOaE': 1,
#          'PAA3neqaErI': 1,
#          '0ASYVB5bwo4': 1,
#          '8NXpfS2wSic': 1,
#          'GljA6W21gPU': 1,
#          'HEeGQ-V6pZA': 1,
#          'Qto12dpPrS0': 1,
#          'qjVuNvfDJVA': 1,
#          'd4OlDh-WkTg': 1,
#          'ea9Byabk7M0': 1,
#          '7Oa2aC1E3H4': 1,
#          'iGoLto7A-E8': 1,
#          'cjin9tPE21s': 1,
#          'ssXatmC1dv0': 3,
#          'dnWT6lV8Zms': 3,
#          'J_JUcnlP2x8': 3,
#          'Wz-jUmc2-Nc': 2,
#          'qzTan067o4Q': 2,
#          'bMtmGmYzyqs': 3,
#          '92oQ1wl2L9w': 2,
#          'cjMMf21G4LQ': 2,
#          'azJEOdKIzuc': 2,
#          'YWaL0JCqwn8': 2,
#          'T2zDipmYKuQ': 3,
#          'RkmRsIMCuGs': 1,
#          'pvpfXupJyIc': 2,
#          '0Fd2PkbxDx8': 1,
#          'oVVW8N7CD4w': 2,
#          'Yf7YncTg1x4': 2,
#          'cH4E_t3m3xM': 2,
#          'frwWD0bMCPQ': 2,
#          'M4BfUCTv5sU': 1,
#          'wFCoThLQ314': 1,
#          '4OFkGrQryfM': 1,
#          'NTPAau4KNPQ': 1,
#          'kQAfFe6ykVA': 1,
#          '4XGD-QEDez8': 2,
#          'gAAe6Jj-6Ss': 1,
#          '2HnNLKkF8wE': 2,
#          'OUxTAobs2ng': 1,
#          'Qymvsuy6gHg': 1,
#          'oMDJVUb_WoI': 2,
#          'kzZo5EPw3fI': 2,
#          'rBmFQuqhl8U': 1,
#          '9kNKAzKfqm8': 2,
#          'RvbsQi4-Uvk': 2,
#          '8zQ9KOA_Zws': 1,
#          'HQZsn_Xmxhc': 1,
#          'IhsoZ4OHNiU': 1,
#          'cTeVM5Vh50k': 1,
#          'VhP-MiErIuI': 1,
#          'YsV-JyLK6lw': 1,
#          'GuuOzrm0t_k': 2,
#          'QKdQFnYT0qA': 1,
#          'PfSE-pGUHeE': 1,
#          'tJP-ltPKEag': 1,
#          'GyNcd0kfnk0': 1,
#          'cE7ySdURSj0': 1,
#          'yTO4Q3M01aM': 1,
#          '2W8OSelMBY8': 1,
#          'P002LvziVVQ': 2,
#          'hlQNk0N7cWk': 1,
#          'sUi_xYFA8TA': 1,
#          '1bqAMbitgHY': 1,
#          'hXB1ZafiZ20': 1,
#          'toJYmS0jHbs': 2,
#          'L4wgpkWugFE': 1,
#          '0B_gSFwnhD4': 1,
#          'wZm6kKSHaog': 2,
#          'AywjUb-EP0Q': 1,
#          'CKJJvVGHi08': 1,
#          'naH20v8A5fg': 1,
#          '6FFAsgvDRVE': 1,
#          '1LfX-xvmiaU': 1,
#          'Nug-xwiL8_0': 1,
#          'ypnZOHq1tVE': 1,
#          'vRbHgtbiGfk': 1,
#          'Vwi3ZbFIPz0': 1,
#          '51J4cOlixeI': 1,
#          'ia9Qz4pnC1g': 1,
#          'ZhhP3N8hb9g': 1,
#          'Qhux3QN2gbc': 1,
#          '5ly4eC-U4P4': 2,
#          'g32CMojhvh4': 1,
#          '6UYc5QMUSeY': 1,
#          'wmepvf8Sag0': 1,
#          'GyNTOVMn1vc': 1,
#          'nF7VyiwLxs0': 1,
#          '0tqMUUMZXPA': 1,
#          '0cGvs-QKHDA': 1,
#          '3_6mRF_gED8': 1,
#          'hjHXJSavVxM': 1,
#          'LDVXOo_HXKU': 1,
#          'DqVNvDuLav0': 1,
#          'Setz0TINv3o': 1,
#          'Q6zLkEhSe50': 1,
#          'JQb3ICATNTM': 1,
#          'O8cljoP08Eo': 1,
#          'iPvwkNmKXBE': 1,
#          'gdX4wXSu_xg': 1,
#          'pFUHsoCchWM': 1,
#          'F5PuQ9uogOg': 1,
#          'mkkjGNHOtAs': 1,
#          'z6tVw2Ercpo': 1,
#          '6Tw_LpsyCzM': 1,
#          '6kWekpDzprM': 1,
#          'gEgu9abhwHs': 1,
#          'wS0joELbcag': 1,
#          'SlRuVqHCtG4': 2,
#          'QGxeUUR7E2Q': 1,
#          'moG5JwbiE1c': 1,
#          'sq6U57oIkxI': 1,
#          'dro9MZjpARw': 1,
#          'RhQaS74hdzA': 1,
#          '4otuLFJg6mM': 1,
#          'wym30pf_UKw': 1,
#          'MO127MPvdZU': 1,
#          'NpMj-73ewM4': 1,
#          '2Yq9BYaSK44': 2,
#          '7z5nazksKBA': 1,
#          ...})

# %%
(mx['video_id'].unique()).shape
# Out:
# (33513,)

# %%
Counter(mx["video_id"].duplicated())
# Out:
# Counter({False: 33513, True: 6938})

# %%
Counter(mx.duplicated())
# Out:
# Counter({False: 40402, True: 49})

# %%
print(mx[mx["video_id"].duplicated() == True] )
# Out:
#           video_id  category_id    views   likes  dislikes  comment_count
# 70          #NAME?           22    57070    6158       118            518
# 86          #NAME?           22     9409      24         2              3
# 219    _OXDcGPVAa4           26  1746221   93269      1792          10285
# 233    hcY52MFWMDM           25   263352     846       393            452
# 258         #NAME?           17   478507    1508       133            523
# ...            ...          ...      ...     ...       ...            ...
# 40419       #NAME?           24    13385     166         8             18
# 40420  WGOi_1XBclQ           10  4233617  436609     11240          56709
# 40426  TXTIMp7En-Q           25    78139    3118      1226           1896
# 40429  L6JFnZ5WabM           24   141734    5012       207           1294
# 40447  i7r_kMbyngk           25   121674    3558        58            491
#
# [6938 rows x 6 columns]

# %%
Counter(mx['video_id'] == 'i7r_kMbyngk')
# Out:
# Counter({False: 40449, True: 2})

# %%
df = mx.drop_duplicates()

# %%
df
# Out:
#           video_id  category_id   views  likes  dislikes  comment_count
# 0      SbOwzAl9ZfQ           24  310130   4182       361           1836
# 1      klOV6Xh-DnI           22  104972    271       174            369
# 2      6L2ZF7Qzsbk           25  136064  10105       266            607
# 3      hcY52MFWMDM           25   96153    378       171            208
# 4      _OXDcGPVAa4           26  499965  57781       681           7428
# ...            ...          ...     ...    ...       ...            ...
# 40446  r63VBOagGAo           17  653114  65639       547           3826
# 40447  i7r_kMbyngk           25  121674   3558        58            491
# 40448  _jnwjdMe3Zo           24   14067    538         6             90
# 40449  pAH9omNAWA4           22   22898     94        11              3
# 40450  dj5Z4jTE3-c           24  108936   5398       148            993
#
# [40402 rows x 6 columns]
